# %%
# !pip install folium
import folium
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/43/77/0287320dc4fd86ae8847bab6c34b5ec370e836a79c7b0c16680a3d9fd770/folium-0.8.3-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/63/36/1c93318e9653f4e414a2e0c3b98fc898b4970e939afeedeee6075dd3b703/branca-0.3.1-py3-none-any.whl
# ...
# distributed 1.21.8 requires msgpack, which is not installed.
# ...
# You are using pip version 10.0.1, however version 19.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
m = folium.Map(location= [33.828362,65.208463], zoom_start=5.5)

# %%
#Jan
locations = {'ghazni': [33.5450587, 68.4173972], 'nangarhar': [34.1718313, 70.6216794], 'takhar': [36.6698013, 69.4784541], 'kandahar': [31.628871, 65.7371749], 'herat': [34.352865, 62.20402869999999], 'baghlan': [35.8042947, 69.2877535], 'samangan': [35.9807296, 67.57085359999999], 'farah': [32.37451, 62.11638], 'badghis': [35.1671339, 63.7695384], 'paktika': [32.2645386, 68.52471489999999], 'khost': [33.3338472, 69.9371673], 'kunduz': [36.7285907, 68.8680663], 'jowzjan': [36.8969692, 65.6658568], 'kabul': [34.5553494, 69.207486], 'faryab': [36.0795613, 64.90595499999999], 'parwan': [34.9630977, 68.81088489999999], 'badakhshan': [36.7347725, 70.81199529999999], 'kapisa': [34.9810572, 69.6214562], 'logar': [34.0145518, 69.1923916], 'sar-e pol': [36.216628, 65.93336], 'balkh': [36.7550603, 66.8975372]}
location_frequency = {'ghazni': 1, 'nangarhar': 3, 'takhar': 1, 'kandahar': 4, 'herat': 2, 'baghlan': 2, 'samangan': 1, 'farah': 1, 'badghis': 1, 'paktika': 1, 'khost': 1, 'kunduz': 2, 'jowzjan': 2, 'kabul': 3, 'faryab': 1, 'parwan': 1, 'badakhshan': 1, 'kapisa': 1, 'logar': 1, 'sar-e pol': 1, 'balkh': 1}

# %%
for key,location in locations.items():
    for i in range(location_frequency[key]):
        folium.Marker(location=location,popup =key, tooltip = location_frequency[key]).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Feb
locations = {'nangarhar': [34.1718313, 70.6216794], 'sar-e pol': [36.216628, 65.93336], 'faryab': [36.0795613, 64.90595499999999], 'samangan': [35.9807296, 67.57085359999999], 'baghlan': [35.8042947, 69.2877535], 'kunduz': [36.7285907, 68.8680663], 'nimruz': [31.0261488, 62.4504154], 'kabul': [34.5553494, 69.207486], 'helmand': [31.363647, 63.958611], 'kandahar': [31.628871, 65.7371749], 'ghazni': [33.5450587, 68.4173972], 'balkh': [36.7550603, 66.8975372], 'laghman': [34.6897687, 70.1455805], 'jowzjan': [36.8969692, 65.6658568]}
location_frequency = {'nangarhar': 3, 'sar-e pol': 1, 'faryab': 1, 'samangan': 1, 'baghlan': 1, 'kunduz': 1, 'nimruz': 1, 'kabul': 2, 'helmand': 1, 'kandahar': 3, 'ghazni': 1, 'balkh': 2, 'laghman': 1, 'jowzjan': 1}

# %%
for key,location in locations.items():
    for i in range(location_frequency[key]):
        folium.Marker(location=location,popup =key, tooltip = location_frequency[key]).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#March
locations= {'balkh': [36.7550603, 66.8975372], 'badghis': [35.1671339, 63.7695384], 'nangarhar': [34.1718313, 70.6216794], 'baghlan': [35.8042947, 69.2877535], 'ghazni': [33.5450587, 68.4173972], 'kandahar': [31.628871, 65.7371749], 'parwan': [34.9630977, 68.81088489999999], 'kunduz': [36.7285907, 68.8680663], 'kunar': [34.8465893, 71.097317], 'ghor': [34.0995776, 64.90595499999999], 'herat': [34.352865, 62.20402869999999], 'kabul': [34.5553494, 69.207486]}
location_frequency = {'helmand': 5, 'faryab': 2, 'balkh': 2, 'kandahar': 3, 'nangarhar': 2, 'kunduz': 1, 'kabul': 3, 'badghis': 1, 'kunar': 1, 'khost': 1, 'ghazni': 2, 'baghlan': 2, 'badakhshan': 1, 'kapisa': 1, 'zabul': 1}

for key,location in locations.items():
    for i in range(location_frequency[key]):
        folium.Marker(location=location,popup =key, tooltip = location_frequency[key]).add_to(m)
        
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#April

locations= {'balkh': [36.7550603, 66.8975372], 'badghis': [35.1671339, 63.7695384], 'nangarhar': [34.1718313, 70.6216794], 'baghlan': [35.8042947, 69.2877535], 'ghazni': [33.5450587, 68.4173972], 'kandahar': [31.628871, 65.7371749], 'parwan': [34.9630977, 68.81088489999999], 'kunduz': [36.7285907, 68.8680663], 'kunar': [34.8465893, 71.097317], 'ghor': [34.0995776, 64.90595499999999], 'herat': [34.352865, 62.20402869999999], 'kabul': [34.5553494, 69.207486]}
location_frequency = {'balkh': 1, 'badghis': 1, 'nangarhar': 4, 'baghlan': 3, 'ghazni': 1, 'kandahar': 1, 'parwan': 1, 'kunduz': 2, 'kunar': 1, 'ghor': 2, 'herat': 1, 'kabul': 1}

for key,location in locations.items():
    for i in range(location_frequency[key]):
        folium.Marker(location=location,popup =key, tooltip = location_frequency[key]).add_to(m)
        
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
